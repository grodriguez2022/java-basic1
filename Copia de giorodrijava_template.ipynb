// %% [markdown]
//  # Java template for **Colaboratory** _notebooks_
//  ## Fonaments

// %%
!apt update -q
!apt-get install -q openjdk-11-jdk-headless
!curl -L https://github.com/SpencerPark/IJava/releases/download/v1.3.0/ijava-1.3.0.zip -o ijava-kernel.zip
!unzip -q ijava-kernel.zip -d ijava-kernel && cd ijava-kernel && python3 install.py --sys-prefix
!jupyter kernelspec list

// %%
System.out.println("Hello World");

// %%
byte b = (byte)128;

// %%
int n=10;
short s=10;
long l=10;

// %%
int m = (int)10L

// %%
byte b = (byte)128;
System.out.println(b);
int k = b;
System.out.println(b)

// %%
float f = 10.5f;

// %%
int p = (int)10.8;
System.out.println(p);

// %%
char c = 'a';
System.out.println(c)

// %%
int h = c;
System.out.println(h)

// %%
int a = 'A' + 1;
System.out.println(a);
char t = (char) a;
System.out.println(t);

// %%
char u = 65;

// %%
byte g = (byte) (10 + 120);
System.out.println(g);

// %%
byte q = (byte)10 + (byte)120;
System.out.println(q);

// %%
int x = (10L + 10L);

// %%
boolean bol1 = false;
boolean bol2 = true;
System.out.println(bol1);
System.out.println(bol2);

// %%
String salutacio = "hola";
System.out.println(salutacio);

// %%
Scanner scn = new Scanner(System.in);
scn.nextLine();

// %%
String input(String str){
System.out.println(str);
Scanner scn = new Scannner

// %%
//suma 
System.out.println(10 + 9);
//Resta
System.out.println(10 - 9);
//Multiplocaciò
System.out.println(10 * 9);
//División entera
System.out.println(10 / 9);
//División decimal
System.out.println(10 / 9.0);

// %%
int n = 4;
int m = 2;
int r = 2* (n / m) + n * m;
System.out.println(r);

// %%
boolean yo = true;
boolean tu = false;

boolean resultAnd = yo && tu;
boolean resultOr = yo || tu;
boolean resultNot = !yo; 

System.out.println (resultAnd);
System.out.println (resultOr);
System.out.println (resultNot);

// %%
! (true || false && true) && ( false || !false)

// %%
6 == 5;
int n = 5;

// %%
int x, y; // declaración de variable, decimos que tipo de dato
x = 6; // asignación 
y = 5; // declaración de variable y asignación al mismo tiempo

System.out.println (6 == 5); //igualdad
System.out.println (6 != 5); //diferente
System.out.println (6 > 5); //mas grande que
System.out.println (6 < 5); //mas pequeño que
System.out.println (x >= y); //mas grande o igual que
System.out.println (x <= y); //mas pequeño o igual que

// %%
int n = 5, m = 10;
int r = n * m;
System.out.println(r);

// %%
boolean yo = true, tu = false;
boolean result = yo && tu;
System.out.println (result);

// %%
boolean res = 6 == 5;
System.out.println (res);

// %%
int b = 6, c = 5, f = 8, t = 12;
boolean me = true, you = false;
boolean res = !(b >= c) || (f > t) && me || you;
System.out.println (res); 
if (!res && res)
System.out.println ("res no es true");
System.out.println ("res no es false");

// %%
int num = 5;
if (num >= 10 && num <= 20);
System.out.println ("true");
else
System.out.println ("false");

// %%
int x = 6;
int v = 55;
// "v es multiplo de x" si v es multiplo x 
// "v no es multiplo de x" en caso contrario
// la operacion modulo % ejemplo: 21 % 7 = 0
// Ejemplo: 16 % 5 = 1
if ( v % x == 0)
  System.out.println ("v es multiplo de x");
else 
   System.out.println ("v no es multiplo de x");

// %%
int v = 35, x = 7;
System.out.printf("v = %d, x = %d%n", v, x);

// %%
System.out.print ("Hola");
System.out.print ("buen día");
System.out.println (" Hola");
System.out.println ("buen día");

// %%
String mon = "World";
int n = 55;
System.out.printf("Hello %s!!! %nBye bye %s%n", mon, n);

// %%
System.out.printf ("número diez mil millones = %,d %n", 10000000000L);

// %%
System.out.printf ("Número pi = %f%n", 3.141592);

// %%
int día = 1;
int mes = 10;
int año = 2017;
System.out.printf ("%02d/%2d/%4d%n", día, mes, año);

// %%
int num = 119;
//true si el número esta entre 10 y 20 incluido
//o esta entre 110 y 120
//falso si no lo esta
if ( num >= 10 $$ <=20);
  System.out.prinln ("true");
else if (num >= 110 $$ num <= 120)
  System.out.println ("true");
else 
  System.out.println("false");

// %%
true petit
int edad = 12;

if (edad >= 18)
    System.out.printf("edad valida: es mayor de edad %n");
else if 
    System.out.printf("edad invalida %n");

// %%
System.out.printf("Hola Mundo");

// %%
//Ejercicios

// %%
byte b0 = 122; b1 = 14;
printf("%d\n", b0 + b1);
System.out.printf("%d\n", b0);
System.out.printf("%d\n", b1);

// %% [markdown]
// Variable de tipo byte

// %%
long b0 = 122;
long b1 =1; //123
int r = (int)(b0 + b1);
printf("%d", r);

// %% [markdown]
// Es una variable tipo long, luego creamos una variable tipo int para hacer la suma

// %%
char c = 'a';
int n = c;
printf("%c\n", c);
printf("%d", n);

// %%
char c = 'a';
short s = c;
printf("%d", s);

// %%
short s = (short)c;
printf("%d", s);

// %%
short s = (short)32000;
println(s);
short s = (short)35000;
print(s);
